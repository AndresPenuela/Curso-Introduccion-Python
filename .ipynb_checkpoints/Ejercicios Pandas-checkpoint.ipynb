# %% [markdown]
# # Ejercicios de Pandas 🐼
# Ahora que hemos aprendido algunos conceptos basicos de la libreria Pandas, vamos a hacer unos cuantos ejercicios, para refrescar ideas y para comprobar que habeis entendido estos conceptos.
# ### 1. Importa la librería Pandas asignandole el nombre *pd* u otro que te guste más.

# %%
import pandas as pd

# %%
rain_df['media'] = rain_df.mean(axis = 1)
rain_df
