# %% [markdown]
# ## Tipos de valores
# ### Numericos, cadenas y booleanos

# %%
bool()
# Out:
# True

# %% [markdown]
# ## Operaciones
# ### Operaciones aritmeticas
# Suma y resta

# %%
3 + 4
# Out:
# 7

# %%
3 - 4
# Out:
# -1

# %% [markdown]
# Multiplicacion y division

# %%
3 * 4

# %%
3 / 4
# Out:
# 0.75

# %% [markdown]
# Exponenciacion

# %%
3**2

# %% [markdown]
# Podemos combinar varias operaciones en una misma expresion

# %%
2 * 4 + 3
# Out:
# 11

# %% [markdown]
# 2 * 4 + 3 = 8 + 3 = 11

# %%
3 + 4 * 2

# %%
(3 + 4) * 2
# Out:
# 14

# %% [markdown]
# O hacer operaciones con cadenas de caracteres

# %%
"Ho" + "la"
# Out:
# 'Hola'

# %%
"Ho" + "la" * 2
# Out:
# 'Holala'

# %% [markdown]
# ### Operaciones de comparacion
# Mayor que

# %%
1 > 2
# Out:
# False

# %% [markdown]
# Menor que

# %%
1 < 2
# Out:
# True

# %% [markdown]
# Igual a

# %%
1 == 2
# Out:
# False

# %%
1 == 1
# Out:
# True

# %% [markdown]
# Podemos combinarlas

# %%
1 <= 2
# Out:
# True

# %% [markdown]
# Pero cuidado con utilizar el = para comparar...

# %%
1 = 2 # es correcta esta expresion? por que?
# Out:
#   File "<ipython-input-74-462cc89bc61a>", line 1
#     1 = 2 # es correcta esta expresion? por que?
#     ^
# SyntaxError: cannot assign to literal

# %% [markdown]
# Distinto a

# %%
1 != 1
# Out:
# False

# %% [markdown]
# ### Operaciones booleanas
# *and*

# %%
True and True
# Out:
# True

# %%
1 == 1 and 3 > 0
# Out:
# True

# %%
True and False
# Out:
# False

# %%
1 == 1 and 3 > 5
# Out:
# False

# %% [markdown]
# *or*

# %%
True or False
# Out:
# True

# %%
1 == 1 or 3 > 5
# Out:
# True

# %% [markdown]
# *not*

# %%
not True
# Out:
# False

# %%
not 1 == 1
# Out:
# False

# %% [markdown]
# ## Variables
# Son como cajas donde guardamos informacion. Esta informacion puede ser numeros (integer o float) o texto.

# %%
a = 3 + 4

# %% [markdown]
# La variable *a* se queda almacenada en la meroria del ordenador y podemos utilizar esta variable cuando queramos a partir de ahora. Nota: debemos asegurarnos de crear la variable antes de utilizarla.

# %%
a

# %%
a + 3

# %% [markdown]
# Como hemos dicho la variable queda almacenada y mantiene el valor que le hemos asignado, pero podemos cambiarlo en cualquier momento si queremos

# %%
a = 120

# %%
a

# %% [markdown]
# Podemos darle cualquier nombre a las variables pero... cuidado con utilizar mayusculas y minusculas:

# %%
A

# %% [markdown]
# ... el nombre de una variable no puede empezar con un numero

# %%
1A = 5

# %%
A1 = 5

# %% [markdown]
# ... tampoco pueden contener espacios

# %%
nombre apellido = 'Juan Lopez'

# %%
nombre_apellido = 'Juan Lopez'

# %% [markdown]
# ...y tampoco podemos usar ciertos nombres ya asignados en Python.

# %%
import = 5

# %% [markdown]
# Nombres que no podemos asignar a variables porque palabras claves (keywords) en Python:
#
# <img src="util/list_keywords.png">
#
# O porque son funciones basicas (built-in functions) de Python:
#
# <img src="util/list_built_in_functions.png">

# %% [markdown]
# Curiosidad: ¿Como podemos mostrar una imagen dentro de un Notebook? (Haz doble click en la celda anterior para ver como)

# %% [markdown]
# ## Condicionales
# Los condicionales se utilizan para ejecutar una expresion en caso de que una o más condiciones se cumplan! Un condicional es como el momento en que se debe tomar una decisión y dependiendo la decisión que se tome ocurrirá una cosa u otra, o ninguna.
#
# *if*: puede traducirse a “sí (se cumple una condicion), entonces:”

# %%
x = 10
if x > 0: # si x es mayor que 0 (condicion), entonces:
    print("la variable x tiene un valor positivo") # muestra en pantalla el mensaje entre parentesis
# Out:
# la variable x tiene un valor positivo

# %% [markdown]
# *else*: puede traducirse como “sino (se cumple la condicion), entonces:” y normalmente se encuentra como escape a un *if*. **Aclaracion:** *else* siempre va acompañando a *if* y debajo de éste.

# %%
x = -5
if x > 0:
    print("la variable x tiene un valor positivo")
else:
    print("la variable x no tiene un valor positivo")
# Out:
# la variable x no tiene un valor positivo

# %% [markdown]
# *elif*: es la abreviacion de "else if" y se utiliza para enlazar varias condiciones, vendría a ser como un “si es”:

# %%
x = -5
if x > 0:
    print("la variable x tiene un valor positivo")
elif x == 0:
    print("la variable x tiene valor 0")
elif x < 0:
    print("la variable x tiene un valor negativo")
# Out:
# la variable x tiene un valor negativo

# %% [markdown]
# ## Funciones basicas de Python

# %%
max(3,5,-1)
# Out:
# 5

# %%
min(3,5,-1)
# Out:
# -1

# %%
abs(-1)
# Out:
# 1

# %%
range(1, 10, 1) # primer elemento: start, segundo elemento: stop, tercer elemento: step
# Out:
# range(1, 10)

# %%
x = range(1,10,1)

# %%
x[0]
# Out:
# 1

# %%
x[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-0bcbedae9f7e> in <module>
# ----> 1 x[10]
#
# IndexError: range object index out of range

# %%
sum(x)
# Out:
# 45

# %%
sum(3,5,-1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-8895781c1339> in <module>
# ----> 1 sum(3,5,-1)
#
# TypeError: sum() takes at most 2 arguments (3 given)

# %%
lista = [3,5,-1]

# %%
sum(lista)
# Out:
# 7

# %%
sum([3,5,-1])
# Out:
# 7

# %% [markdown]
# Mejor que utilizar listas, a partir de ahora vamos a utilizar matrices, que en Python se conocen como *array*. Para poder crear matrices y operar con ellas necesitamos importar una biblioteca de funciones muy conocida en el mundo Python llamada **Numpy**
# ## Bibliotecas de funciones
# ### Numpy
